# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#Reading raw file
states_data = read_csv("data/SAGDP2N__ALL_AREAS_1997_2021.csv")

head(states_data)
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 4512 Columns: 28
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (14): GeoName, Description, Unit, 2000, 2005, 2006, 2007, 2008, 2009, 20...
# dbl (14): 1997, 1998, 1999, 2001, 2002, 2003, 2004, 2010, 2012, 2014, 2015, ...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GeoName Description        Unit                        1997     1998
# 1 Alabama All industry total Millions of current dollars 104811.9 110212.0
# 2 Alabama Manufacturing      Millions of current dollars  19602.7  20567.0
# 3 Alaska  All industry total Millions of current dollars  25810.8  24227.5
# 4 Alaska  Manufacturing      Millions of current dollars    870.0   1118.9
# 5 Arizona All industry total Millions of current dollars 132281.0 143302.6
# 6 Arizona Private industries Millions of current dollars 114429.6 124318.1
#   1999     2000     2001     2002     2003     ⋯ 2012     2013     2014
# 1 115680.1 119851.7 122915.5 127505.0 134152.6 ⋯ 189245.5 194786.9 197406.9
# 2  21461.7 21694.1   21189.7  21250.8  21744.9 ⋯  32058.7 33737     33352.5
# 3  24744.3 26806.6   28494.1  29756.8  32037.9 ⋯  58283.6 57247.7   56484.9
# 4    884.3 829.9       948.1    919.2   1101.9 ⋯    992.0 1325       1597.4
# 5 155755.8 165110.7 171909.6 180522.3 193634.9 ⋯ 271440.0 278591.6 287666.6
# 6 135756.6 144042.8 149169.9 156331.4 167732.7 ⋯ 233709.9 240043.3 249015.1
#   2015     2016     2017     2018     2019     2020     2021
# 1 202372.4 207368.4 215085.9 224046.9 231171.8 226896.5 247092.5
# 2  33529.3  34464.3 36146.6   38064.9 37528.1   35733.7 40062.4
# 3  51490.9  50727.7 53089.3   54711.7 54547.1   49820.0 54970.1
# 4   1833.6   1570.4 1821.9     1420.2 1488.9     1338.8 (D)
# 5 299393.3 313081.4 330416.1 349907.5 369988.2 373719.0 411191.8
# 6 259826.4 272463.6 288024.8 306447.4 325361.5 327118.2 363866.2

# %%
##Rename the columns
#Added letter "y" as it causes some issues
colnames(states_data) = c("state_name", "description", "unit", "y1997", "y1998", "y1999", "y2000", "y2001", "y2002", "y2003", "y2004", "y2005", "y2006", "y2007", "y2008", "y2009", "y2010", "y2011", "y2012", "y2013", "y2014", "y2015", "y2016", "y2017", "y2018", "y2019", "y2020", "y2021")

#Some data columns were classified as characters due to "(NA)" values which would cause pivotting errors
#Fixing all columns to be double

states_data$y1997 = as.double(states_data$y1997)
states_data$y1998 = as.double(states_data$y1998)
states_data$y1999 = as.double(states_data$y1999)
states_data$y2000 = as.double(states_data$y2000)
states_data$y2001 = as.double(states_data$y2001)
states_data$y2002 = as.double(states_data$y2002)
states_data$y2003 = as.double(states_data$y2003)
states_data$y2004 = as.double(states_data$y2004)
states_data$y2005 = as.double(states_data$y2005)
states_data$y2006 = as.double(states_data$y2006)
states_data$y2007 = as.double(states_data$y2007)
states_data$y2008 = as.double(states_data$y2008)
states_data$y2009 = as.double(states_data$y2009)
states_data$y2010 = as.double(states_data$y2010)
states_data$y2011 = as.double(states_data$y2011)
states_data$y2012 = as.double(states_data$y2012)
states_data$y2013 = as.double(states_data$y2013)
states_data$y2014 = as.double(states_data$y2014)
states_data$y2015 = as.double(states_data$y2015)
states_data$y2016 = as.double(states_data$y2016)
states_data$y2017 = as.double(states_data$y2017)
states_data$y2018 = as.double(states_data$y2018)
states_data$y2019 = as.double(states_data$y2019)
states_data$y2020 = as.double(states_data$y2020)
states_data$y2021 = as.double(states_data$y2021)

head(states_data)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
#   state_name description        unit                        y1997    y1998
# 1 Alabama    All industry total Millions of current dollars 104811.9 110212.0
# 2 Alabama    Manufacturing      Millions of current dollars  19602.7  20567.0
# 3 Alaska     All industry total Millions of current dollars  25810.8  24227.5
# 4 Alaska     Manufacturing      Millions of current dollars    870.0   1118.9
# 5 Arizona    All industry total Millions of current dollars 132281.0 143302.6
# 6 Arizona    Private industries Millions of current dollars 114429.6 124318.1
#   y1999    y2000    y2001    y2002    y2003    ⋯ y2012    y2013    y2014
# 1 115680.1 119851.7 122915.5 127505.0 134152.6 ⋯ 189245.5 194786.9 197406.9
# 2  21461.7  21694.1  21189.7  21250.8  21744.9 ⋯  32058.7  33737.0  33352.5
# 3  24744.3  26806.6  28494.1  29756.8  32037.9 ⋯  58283.6  57247.7  56484.9
# 4    884.3    829.9    948.1    919.2   1101.9 ⋯    992.0   1325.0   1597.4
# 5 155755.8 165110.7 171909.6 180522.3 193634.9 ⋯ 271440.0 278591.6 287666.6
# 6 135756.6 144042.8 149169.9 156331.4 167732.7 ⋯ 233709.9 240043.3 249015.1
#   y2015    y2016    y2017    y2018    y2019    y2020    y2021
# 1 202372.4 207368.4 215085.9 224046.9 231171.8 226896.5 247092.5
# 2  33529.3  34464.3  36146.6  38064.9  37528.1  35733.7  40062.4
# 3  51490.9  50727.7  53089.3  54711.7  54547.1  49820.0  54970.1
# 4   1833.6   1570.4   1821.9   1420.2   1488.9   1338.8       NA
# 5 299393.3 313081.4 330416.1 349907.5 369988.2 373719.0 411191.8
# 6 259826.4 272463.6 288024.8 306447.4 325361.5 327118.2 363866.2

# %%
#Filter for only "All industry total" and "Manufacturing"

states_reduced = states_data %>%
    filter(description == "All industry total" | description == "Manufacturing")

#Bringing back numbered columns
colnames(states_reduced) = c("state_name", "description", "unit", "1997", "1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021")

head(states_reduced)
# Out:
#   state_name description        unit                        1997     1998
# 1 Alabama    All industry total Millions of current dollars 104811.9 110212.0
# 2 Alabama    Manufacturing      Millions of current dollars  19602.7  20567.0
# 3 Alaska     All industry total Millions of current dollars  25810.8  24227.5
# 4 Alaska     Manufacturing      Millions of current dollars    870.0   1118.9
# 5 Arizona    All industry total Millions of current dollars 132281.0 143302.6
# 6 Arizona    Manufacturing      Millions of current dollars  21453.7  22215.9
#   1999     2000     2001     2002     2003     ⋯ 2012     2013     2014
# 1 115680.1 119851.7 122915.5 127505.0 134152.6 ⋯ 189245.5 194786.9 197406.9
# 2  21461.7  21694.1  21189.7  21250.8  21744.9 ⋯  32058.7  33737.0  33352.5
# 3  24744.3  26806.6  28494.1  29756.8  32037.9 ⋯  58283.6  57247.7  56484.9
# 4    884.3    829.9    948.1    919.2   1101.9 ⋯    992.0   1325.0   1597.4
# 5 155755.8 165110.7 171909.6 180522.3 193634.9 ⋯ 271440.0 278591.6 287666.6
# 6  23932.4  22983.3  22227.9  22335.1  25649.5 ⋯  24505.2  22226.4  24070.0
#   2015     2016     2017     2018     2019     2020     2021
# 1 202372.4 207368.4 215085.9 224046.9 231171.8 226896.5 247092.5
# 2  33529.3  34464.3  36146.6  38064.9  37528.1  35733.7  40062.4
# 3  51490.9  50727.7  53089.3  54711.7  54547.1  49820.0  54970.1
# 4   1833.6   1570.4   1821.9   1420.2   1488.9   1338.8       NA
# 5 299393.3 313081.4 330416.1 349907.5 369988.2 373719.0 411191.8
# 6  25819.2  26489.1  28652.4  31427.6  33304.5  32067.7  34995.1

# %%
#Pivot Longer/rename
states_pivotted = states_reduced %>%
    pivot_longer(cols = "1997":"2021" ,
                 names_to = "year",
                 values_to = "current_dollars_millions") %>%
    select(-unit)  #unit column is redundant

states_pivotted$year = as.integer(states_pivotted$year) #convert year to an integer

head(states_pivotted)
# Out:
#   state_name description        year current_dollars_millions
# 1 Alabama    All industry total 1997 104811.9
# 2 Alabama    All industry total 1998 110212.0
# 3 Alabama    All industry total 1999 115680.1
# 4 Alabama    All industry total 2000 119851.7
# 5 Alabama    All industry total 2001 122915.5
# 6 Alabama    All industry total 2002 127505.0

# %%
#Calculating the fraction

states_percentage_long = states_pivotted %>%
    group_by(state_name, year) %>%        #group variables by state then year -- creating the pairs of "Manufacturing" and "All" for each year
    summarize(percentage_manufacturing = min(current_dollars_millions)/max(current_dollars_millions))  #since each grouping only contains two numbers, we can simply divide smaller by larger to get percentage

head(states_percentage_long)
tail(states_percentage_long)
# Out:
# `summarise()` has grouped output by 'state_name'. You can override using the `.groups` argument.
#   state_name year percentage_manufacturing
# 1 Alabama    1997 0.1870274
# 2 Alabama    1998 0.1866131
# 3 Alabama    1999 0.1855263
# 4 Alabama    2000 0.1810079
# 5 Alabama    2001 0.1723924
# 6 Alabama    2002 0.1666664
#   state_name year percentage_manufacturing
# 1 Wyoming    2016 0.04795284
# 2 Wyoming    2017 0.05903640
# 3 Wyoming    2018 0.07028026
# 4 Wyoming    2019 0.07677623
# 5 Wyoming    2020 0.07009236
# 6 Wyoming    2021 0.06485210

# %%
states_percentage_wide = states_percentage_long %>%
    pivot_wider(names_from = year,
                values_from = percentage_manufacturing)

head(states_percentage_wide)
# Out:
#   state_name 1997       1998       1999       2000       2001       2002
# 1 Alabama    0.18702743 0.18661307 0.18552629 0.18100786 0.17239242 0.16666641
# 2 Alaska     0.03370682 0.04618306 0.03573752 0.03095879 0.03327355 0.03089042
# 3 Arizona    0.16218278 0.15502789 0.15365335 0.13919934 0.12929993 0.12372488
# 4 Arkansas   0.22376321 0.21597617 0.21959459 0.21188873 0.19633175 0.19827994
# 5 California 0.14572162 0.14226954 0.14416414 0.15169516 0.12921762 0.11443825
# 6 Colorado   0.10507624 0.09661811 0.08877142 0.08810295 0.07765520 0.07829164
#   2003       2004       2005       ⋯ 2012       2013       2014
# 1 0.16209078 0.17878729 0.17629880 ⋯ 0.16940271 0.17319953 0.16895306
# 2 0.03439364 0.03460388 0.03133564 ⋯ 0.01702023 0.02314503 0.02828012
# 3 0.13246321 0.10426496 0.09031621 ⋯ 0.09027851 0.07978130 0.08367325
# 4 0.19146046 0.19104198 0.18539362 ⋯ 0.14057337 0.14772851 0.15206726
# 5 0.11810835 0.11578064 0.12282507 ⋯ 0.11261569 0.11316472 0.11345983
# 6 0.07406546 0.07725874 0.07646579 ⋯ 0.07538641 0.07293169 0.07215162
#   2015       2016       2017       2018       2019       2020       2021
# 1 0.16568119 0.16619842 0.16805658 0.16989702 0.16233857 0.15748899 0.16213523
# 2 0.03561018 0.03095745 0.03431765 0.02595788 0.02729568 0.02687274         NA
# 3 0.08623840 0.08460771 0.08671611 0.08981688 0.09001503 0.08580698 0.08510651
# 4 0.14979522 0.14731638 0.14587880 0.15018793 0.15034787 0.14537742 0.14751006
# 5 0.11321507 0.11112166 0.11531989 0.11866909 0.11678557 0.11852795 0.12318013
# 6 0.07249445 0.06912425 0.06542741 0.06476981 0.06487668 0.06498378 0.06576837

# %%
#Saving file into output_files folder
write_csv(states_percentage_long, "output_files/percentage_manufacturing_long.csv")

write_csv(states_percentage_wide, "output_files/percentage_manufacturing_wide.csv")

# %%
#Calculations to confirm procedures were done correctly
states_analysis = states_percentage_long %>%
    group_by(state_name) %>%
    summarize(obs = n())

states_analysis  #There are 50 states and 1 city in the data set, all of which have 25 calculations for the 25 years 1997-2021. This confirms that no year was left out.
#There is 1275 rows in states_percentage_long which matches perfectly
# Out:
#    state_name           obs
# 1  Alabama              25
# 2  Alaska               25
# 3  Arizona              25
# 4  Arkansas             25
# 5  California           25
# 6  Colorado             25
# 7  Connecticut          25
# 8  Delaware             25
# 9  District of Columbia 25
# 10 Florida              25
# 11 Georgia              25
# 12 Hawaii               25
# 13 Idaho                25
# 14 Illinois             25
# 15 Indiana              25
# 16 Iowa                 25
# 17 Kansas               25
# 18 Kentucky             25
# 19 Louisiana            25
# 20 Maine                25
# 21 Maryland             25
# 22 Massachusetts        25
# 23 Michigan             25
# 24 Minnesota            25
# 25 Mississippi          25
# 26 Missouri             25
# 27 Montana              25
# 28 Nebraska             25
# 29 Nevada               25
# 30 New Hampshire        25
# 31 New Jersey           25
# 32 New Mexico           25
# 33 New York             25
# 34 North Carolina       25
# 35 North Dakota         25
# 36 Ohio                 25
# 37 Oklahoma             25
# 38 Oregon               25
# 39 Pennsylvania         25
# 40 Rhode Island         25
# 41 South Carolina       25
# 42 South Dakota         25
# 43 Tennessee            25
# 44 Texas                25
# 45 Utah                 25
# 46 Vermont              25
# 47 Virginia             25
# 48 Washington           25
# 49 West Virginia        25
# 50 Wisconsin            25
# 51 Wyoming              25
